# %%
import pandas as pd
import numpy as np

# %%
acc = pd.read_csv("../data/raw/ravenstack_accounts.csv")
churn = pd.read_csv("../data/raw/ravenstack_churn_events.csv")
features = pd.read_csv("../data/raw/ravenstack_feature_usage.csv")
subs = pd.read_csv("../data/raw/ravenstack_subscriptions.csv")
support = pd.read_csv("../data/raw/ravenstack_support_tickets.csv")

# %%
acc.head()

# %%
churn.head()

# %%
features.head()

# %%
subs.head()

# %%
support.head()
